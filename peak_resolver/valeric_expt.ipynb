# %%
import pandas as pd
from peak_resolver.process_chromeleon import *
from ib_mpl_stylesheet.ib_mpl_stylesheet import ib_mpl_style
plt.style.use(ib_mpl_style)

# %% [markdown]
# ### Read run 1

# %%
ddesc = 'Valeric only'
pt = 's'

# %%
numbers = [0, 1, 2, 3, 4]
fpath = '/Users/ianbillinge/Documents/yiplab/projects/org_acids_iems/Fanny Raw IC Data/Experiment Results/3) VALERIC ACID/'
fsamps = process_conc_series(fpath + '/RUN 1/F', '-V1_2023_11_23.txt', numbers = numbers, tmin=0, tmax = 20)
rsamps = process_conc_series(fpath + '/RUN 1/R', '-V1_2023_11_23.txt', numbers = numbers, tmin=0, tmax = 20)

# %%
plot_experiment(fsamps, rsamps, run=1, desc = ddesc, plot_type=pt, 
                savefig=fpath + 'RUN 1/valeric_run1.pdf', legend=True)
# Out:
# initializing a plot
# (<Figure size 1000x800 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %% [markdown]
# ### Read Run 2

# %%
numbers = [0, 1, 2, 3, 4]
fsamps = process_conc_series(fpath + '/RUN 2/F', '-V2_2023_11_23.txt', numbers = numbers, tmin=0, tmax = 20)
rsamps = process_conc_series(fpath + '/RUN 2/R', '-V2_2023_11_23.txt', numbers = numbers, tmin=0, tmax = 20)

# %%
plot_experiment(fsamps, rsamps, run=2, desc = ddesc, plot_type=pt, 
                savefig=fpath + 'RUN 2/valeric_run2.pdf', legend=True)
# Out:
# initializing a plot
# (<Figure size 1000x800 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %% [markdown]
# ### Read Run 3

# %%
numbers = [0, 1, 2, 3, 4]
fsamps = process_conc_series(fpath + 'RUN 3/F', '-V3_2023_11_28.txt', numbers = numbers, tmin=0, tmax = 20)
rsamps = process_conc_series(fpath + 'RUN 3/R', '-V3_2023_11_28.txt', numbers = numbers, tmin=0, tmax = 20)

# %%
plot_experiment(fsamps, rsamps, run=3, desc = ddesc, plot_type=pt, 
                savefig=fpath + 'RUN 3/valeric_run3.pdf', legend=True)
# Out:
# initializing a plot
# (<Figure size 1000x800 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))
